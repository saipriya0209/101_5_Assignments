# %% [markdown]
# <font size="5">**Initial Data Cleaning and Selection**</font>

# %% [markdown]
# <font size="3">**Load data**

# %%
import numpy as np # linear algebra
import pandas as pd # data processing

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# save filepath to variable for easier access
opioid_filepath = '../data/VSRR_Provisional_Drug_Overdose_Death_Counts.csv'

# read the data and store data in DataFrame 
opioid_data = pd.read_csv(opioid_filepath)

# %% [markdown]
# <font size="3">**Initial look at data**

# %%
opioid_data.head()
# Out:
#   State  Year  Month           Period  \
# 0    AK  2015  April  12 month-ending
# 1    AK  2015  April  12 month-ending
# 2    AK  2015  April  12 month-ending
# 3    AK  2015  April  12 month-ending
# 4    AK  2015  April  12 month-ending
#
#                                            Indicator  Data Value  \
# 0  Natural, semi-synthetic, & synthetic opioids, ...         NaN
# 1           Natural & semi-synthetic opioids (T40.2)         NaN
# 2  Natural & semi-synthetic opioids, incl. methad...         NaN
# 3                                   Number of Deaths      4133.0
# 4                        Opioids (T40.0-T40.4,T40.6)         NaN
#
#   Percent Complete  Percent Pending Investigation State Name  \
# 0              100                            0.0     Alaska
# 1              100                            0.0     Alaska
# 2              100                            0.0     Alaska
# 3              100                            0.0     Alaska
# 4              100                            0.0     Alaska
#
#                                             Footnote Footnote Symbol  \
# 0  Numbers may differ from published reports usin...              **
# 1  Numbers may differ from published reports usin...              **
# 2  Numbers may differ from published reports usin...              **
# 3  Numbers may differ from published reports usin...              **
# 4  Numbers may differ from published reports usin...              **
#
#   Predicted Value
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %%
opioid_data.tail()
# Out:
#       State  Year  Month           Period  \
# 41620    YC  2021  March  12 month-ending
# 41621    YC  2021  March  12 month-ending
# 41622    YC  2021  March  12 month-ending
# 41623    YC  2021  March  12 month-ending
# 41624    YC  2021  March  12 month-ending
#
#                                                Indicator  Data Value  \
# 41620                                    Cocaine (T40.5)      908.00
# 41621                       Percent with drugs specified       99.06
# 41622  Natural, semi-synthetic, & synthetic opioids, ...     1853.00
# 41623  Natural & semi-synthetic opioids, incl. methad...      672.00
# 41624         Synthetic opioids, excl. methadone (T40.4)     1718.00
#
#       Percent Complete  Percent Pending Investigation     State Name  \
# 41620              100                       0.258858  New York City
# 41621              100                       0.258858  New York City
# 41622              100                       0.258858  New York City
# 41623              100                       0.258858  New York City
# 41624              100                       0.258858  New York City
#
#                                     Footnote Footnote Symbol Predicted Value
# 41620  Underreported due to incomplete data.               *             937
# 41621  Underreported due to incomplete data.               *             NaN
# 41622  Underreported due to incomplete data.               *           1,914
# 41623  Underreported due to incomplete data.               *             693
# 41624  Underreported due to incomplete data.               *           1,778

# %% [markdown]
# The data includes New York City, which isn't a state, so we'll need to take another look at the full data later.

# %%
opioid_data.dtypes
# Out:
# State                             object
# Year                               int64
# Month                             object
# Period                            object
# Indicator                         object
# Data Value                       float64
# Percent Complete                  object
# Percent Pending Investigation    float64
# State Name                        object
# Footnote                          object
# Footnote Symbol                   object
# Predicted Value                   object
# dtype: object

# %% [markdown]
# Here, "Year" is an integer, so we'll need to reformat this later.

# %%
opioid_data.shape
# Out:
# (41625, 12)

# %% [markdown]
# <font size="3">**Removing Columns**

# %%
# Selecting columns
opioid_features = ['State', 'Year', 'Month', 'Indicator', 'Data Value', 'State Name']
# Creating new dataframe with selected columns
selected_opioid_data = opioid_data[opioid_features]
# Reviewing new dataframe
selected_opioid_data.head()
# Out:
#   State  Year  Month                                          Indicator  \
# 0    AK  2015  April  Natural, semi-synthetic, & synthetic opioids, ...
# 1    AK  2015  April           Natural & semi-synthetic opioids (T40.2)
# 2    AK  2015  April  Natural & semi-synthetic opioids, incl. methad...
# 3    AK  2015  April                                   Number of Deaths
# 4    AK  2015  April                        Opioids (T40.0-T40.4,T40.6)
#
#    Data Value State Name
# 0         NaN     Alaska
# 1         NaN     Alaska
# 2         NaN     Alaska
# 3      4133.0     Alaska
# 4         NaN     Alaska

# %% [markdown]
# <font size="3">**Merging "Year" and "Month" to form a new "Date" Column**

# %% [markdown]
# This still leaves us with the need to change the "Year" column to a String and to merge the "Year" and "Month" together into a single Date. We then need to parse the Date together into a format the notebook can recognise as a Date.

# %%
# Changing all data to String
selected_opioid_data = selected_opioid_data.astype(str)

# %%
# Confirming the "Year" column changed to String
selected_opioid_data.dtypes
# Out:
# State         object
# Year          object
# Month         object
# Indicator     object
# Data Value    object
# State Name    object
# dtype: object

# %%
# Joining the "Month" and "Year" columns together
selected_opioid_data["Date"] = selected_opioid_data["Month"] + " " + selected_opioid_data["Year"]
# Taking a look at the new dataframe
selected_opioid_data.head()
# Out:
#   State  Year  Month                                          Indicator  \
# 0    AK  2015  April  Natural, semi-synthetic, & synthetic opioids, ...
# 1    AK  2015  April           Natural & semi-synthetic opioids (T40.2)
# 2    AK  2015  April  Natural & semi-synthetic opioids, incl. methad...
# 3    AK  2015  April                                   Number of Deaths
# 4    AK  2015  April                        Opioids (T40.0-T40.4,T40.6)
#
#   Data Value State Name        Date
# 0        nan     Alaska  April 2015
# 1        nan     Alaska  April 2015
# 2        nan     Alaska  April 2015
# 3     4133.0     Alaska  April 2015
# 4        nan     Alaska  April 2015

# %% [markdown]
# Looks good

# %%
# Now we will parse the Date so that the notebook can read it as an actual date
import datetime
selected_opioid_data['Date_parsed'] = pd.to_datetime(selected_opioid_data['Date'], format="%B %Y")
# Seeing how it looks
selected_opioid_data['Date_parsed'].head()
# Out:
# 0   2015-04-01
# 1   2015-04-01
# 2   2015-04-01
# 3   2015-04-01
# 4   2015-04-01
# Name: Date_parsed, dtype: datetime64[ns]

# %% [markdown]
# That looks good. And for the full dataframe:

# %%
selected_opioid_data.head()
# Out:
#   State  Year  Month                                          Indicator  \
# 0    AK  2015  April  Natural, semi-synthetic, & synthetic opioids, ...
# 1    AK  2015  April           Natural & semi-synthetic opioids (T40.2)
# 2    AK  2015  April  Natural & semi-synthetic opioids, incl. methad...
# 3    AK  2015  April                                   Number of Deaths
# 4    AK  2015  April                        Opioids (T40.0-T40.4,T40.6)
#
#   Data Value State Name        Date Date_parsed
# 0        nan     Alaska  April 2015  2015-04-01
# 1        nan     Alaska  April 2015  2015-04-01
# 2        nan     Alaska  April 2015  2015-04-01
# 3     4133.0     Alaska  April 2015  2015-04-01
# 4        nan     Alaska  April 2015  2015-04-01

# %%
# Setting the Parsed Date (that the notebook can read as a date) to the index column for easier analysis later on
date_indexed_opioid_data = selected_opioid_data.set_index('Date_parsed')
# Taking a look
date_indexed_opioid_data.head()
# Out:
#             State  Year  Month  \
# Date_parsed
# 2015-04-01     AK  2015  April
# 2015-04-01     AK  2015  April
# 2015-04-01     AK  2015  April
# 2015-04-01     AK  2015  April
# 2015-04-01     AK  2015  April
#
#                                                      Indicator Data Value  \
# Date_parsed
# 2015-04-01   Natural, semi-synthetic, & synthetic opioids, ...        nan
# 2015-04-01            Natural & semi-synthetic opioids (T40.2)        nan
# 2015-04-01   Natural & semi-synthetic opioids, incl. methad...        nan
# 2015-04-01                                    Number of Deaths     4133.0
# 2015-04-01                         Opioids (T40.0-T40.4,T40.6)        nan
#
#             State Name        Date
# Date_parsed
# 2015-04-01      Alaska  April 2015
# 2015-04-01      Alaska  April 2015
# 2015-04-01      Alaska  April 2015
# 2015-04-01      Alaska  April 2015
# 2015-04-01      Alaska  April 2015

# %% [markdown]
# Looks good.

# %% [markdown]
# Writing the clean data into a csv so we can visualize

# %%
# Setting the Indicator to only look at the "Number of Drug Overdose Deaths"
Num_of_deaths_data = date_indexed_opioid_data[date_indexed_opioid_data.Indicator == 'Number of Drug Overdose Deaths']
# Taking a look
Num_of_deaths_data.head()

# Selecting columns
opioid_features = ['State', 'Year', 'Month', 'Data Value', 'State Name']
# Creating new dataframe with selected columns
Num_of_deaths_data = Num_of_deaths_data[opioid_features]

Num_of_deaths_data.to_csv("../data/Clean_Opioids-in-the-us-data.csv")
